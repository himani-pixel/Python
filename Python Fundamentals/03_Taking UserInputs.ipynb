# %% [markdown]
# # Taking User Input in Python
# ## Using the `input()` Function
# - The `input()` function allows you to take user input from the keyboard.
# - By default, `input()` returns a string. You can convert it to other data types as needed.
# - Examples:

# %%
name = str(input("Enter your name: "))
age = int(input("Enter your age: "))
print(f"My name is {name} and my age is {age} yrs old.")
# Out:
# Enter your name:  Himani
# Enter your age:  19
# My name is Himani and my age is 19 yrs old.
