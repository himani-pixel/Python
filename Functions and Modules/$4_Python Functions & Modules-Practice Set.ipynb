# %% [markdown]
# ## <b>Python Functions & Modules – Practice Set</b>
# This set is based on the topics we’ve covered so far:
#
# - <b>Defining Functions in Python</b>
# - <b>Function Arguments & Return Values</b>
# - <b>Lambda Functions in Python</b>
# - <b>Recursion in Python</b>
# - <b>Modules and Pip – Using External Libraries</b>
# - <b>Variable Scope and Docstrings</b>
#
# These exercises will help you get hands-on practice with writing functions, understanding arguments, using recursion, and working with external libraries.

# %% [markdown]
# ### <b>1. Defining Functions</b>
# 1. Write a function `greet()` that prints `"Hello, Python Learner!"` when called.
# 2. Write a function `square(num)` that returns the square of a given number. Test it with different numbers.

# %%
#1.
def greet():
    return "Hello, Python Learner."
print(greet())

#2.
def square(num):
    return num*num
n = int(input("Enter a number:"))
print("Square of ",n,"is:",square(n))
# Out:
# Hello, Python Learner.
# Enter a number: 5
# Square of  5 is: 25

# %% [markdown]
# ### <b>2. Function Arguments & Return Values</b>
# 1. Write a function `full_name(first, last)` that takes first name and last name as parameters and returns a single string in the format `"First Last"`.
#
# 2.Write a function `calculate_area(length, width=10)` that returns the area of a rectangle. Test it by calling the function with:
# - Both` length `and `width`
# - Only `length` (use default width)

# %%
#1. 
def fullName(firstName , lastName):
    return f"{firstName} {lastName}."
f_name = input("Enter you first name:")
l_name = input("Enter you last name:")
print(fullName(f_name , l_name))

#2.
def Area_of_Rectangle(lenght , width):
    return lenght * width
l = int(input("Enter the lenght of the rectangle:"))
w = int(input("Enter the width of the rectangle:"))
print("The area of rectangle is:",Area_of_Rectangle(l,w))

#2. (width default width)
def area_of_rectangle(lenght , width):
    return lenght * width
lenght = int(input("Enter the lenght of the rectangle:"))
width = 10
print("The area of rectangle is:",area_of_rectangle(lenght , width))
# Out:
# Enter you first name: Himani
# Enter you last name: Malankar
# Himani Malankar.
# Enter the lenght of the rectangle: 12
# Enter the width of the rectangle: 12
# The area of rectangle is: 144
# Enter the lenght of the rectangle: 12
# The area of rectangle is: 120

# %% [markdown]
# ### <b>3. Lambda Functions</b>
# 1. Write a lambda function that adds two numbers and test it.
# 2. Create a list `[1, 2, 3, 4, 5]` and use `map()` with a lambda function to get their squares.

# %%
#1.
a = int(input("Enter a :"))
b = int(input("Enter b:"))
result = lambda  : a + b 
print("Result:",result())

#2.
lst = [3 , 6 , 9 , 12 , 15 ]
square = list(map(lambda x : x**2 , lst))
print("Square of the list is:",square)
# Out:
# Enter a : 37
# Enter b: 12
# Result: 49
# Square of the list is: [9, 36, 81, 144, 225]

# %% [markdown]
# ### <b>4. Recursion in Python</b>
# 1. Write a recursive function `factorial(n)` that returns the factorial of a number.
# 2. Write a recursive function` sum_of_digits(n)` that returns the sum of all digits of a given number.

# %%
#1.
def factorial(number):
    if number == 0 or number == 1:
        return 1
    return number * factorial(number-1)
num = int(input("Enter a number:"))
print("Factorial of number",num, "is:",factorial(num))

#2.
def sum_of_digit(n):
    if n == 0:
        return 0
    return (n % 10) + sum_of_digit(n // 10)
n = int(input("Enter a number:"))
print("Sum of digits:",sum_of_digit(n))
# Out:
# Enter a number: 7
# Factorial of number 7 is: 5040
# Enter a number: 37
# Sum of digits: 10

# %% [markdown]
# ### <b>5. Modules and Pip – Using External Libraries</b>
# 1. Import the math module and use it to:
# - Find the square root of 144
# - Calculate` sin(90°)` (hint: use `math.radians()`)

# %%
#1.
import math
print("Square Root of 144 is:",math.sqrt(144))
# Out:
# Square Root of 144 is: 12.0

# %%
#1.
def fibonacci(n1):
    if n1 == 0:
        return 1
    elif n1 == 1:
        return 1
    return fibonacci(n1-1) + fibonacci(n1-2)
NUM = int(input("Enter a number to print fibonacci series:"))
for i in range(NUM):
    print(fibonacci(i) , end = " , ")

#2. 
def safe_divide(a,b):
    if a == 0 or b == 0:
        print("Zero cannot be divisible by any number.")
    else:
        return a/b
a = int(input("Enter a:"))
b = int(input("Enter b:"))
safe_divide(a,b)
# Out:
# Enter a number to print fibonacci series: 7
# 1 , 1 , 2 , 3 , 5 , 8 , 13 ,
# Enter a: 0
# Enter b: 11
# Zero cannot be divisible by any number.
